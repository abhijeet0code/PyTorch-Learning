# %% [markdown]
# -> "Steps to follow in the creation of the model"
#
# 1. Create a dataset (Prepare it and load it).
# 2. Build a model.
# 3. Fitting the model to the data training.
# 4. Making a prediction in the (Inference mode)
# 5. Saving and loading the model to use it.

# %%
#Basic things require for the model to be build 

import torch
from torch import nn
import matplotlib.pyplot as plt
from pathlib import Path

# %%
#The weights and bias for the linear regression formula
weight=0.5
bias=0.3

#Defining the input of the model in the linear regression model
x=torch.arange(0,1,0.02).unsqueeze(dim=1)

y=weight*x+bias

# %%
#Creating the data set to model get trained on 
train_split=int(0.8*len(x))
x_train=x[:train_split]
x_label=y[:train_split]

y_test=x[train_split:]
y_label=y[train_split:]

print(f"The model training set are {x_train} and the preds are {x_label}")
print(f"The model test sets are {y_test} and the preds are {y_label}")
# Out:
# The model training set are tensor([[0.0000],
#         [0.0200],
#         [0.0400],
#         [0.0600],
#         [0.0800],
#         [0.1000],
#         [0.1200],
#         [0.1400],
#         [0.1600],
#         [0.1800],
#         [0.2000],
#         [0.2200],
#         [0.2400],
#         [0.2600],
#         [0.2800],
#         [0.3000],
#         [0.3200],
#         [0.3400],
#         [0.3600],
#         [0.3800],
#         [0.4000],
#         [0.4200],
#         [0.4400],
#         [0.4600],
#         [0.4800],
#         [0.5000],
#         [0.5200],
#         [0.5400],
#         [0.5600],
#         [0.5800],
#         [0.6000],
#         [0.6200],
#         [0.6400],
#         [0.6600],
#         [0.6800],
#         [0.7000],
#         [0.7200],
#         [0.7400],
#         [0.7600],
#         [0.7800]]) and the preds are tensor([[0.3000],
#         [0.3100],
#         [0.3200],
#         [0.3300],
#         [0.3400],
#         [0.3500],
#         [0.3600],
#         [0.3700],
#         [0.3800],
#         [0.3900],
#         [0.4000],
#         [0.4100],
#         [0.4200],
#         [0.4300],
#         [0.4400],
#         [0.4500],
#         [0.4600],
#         [0.4700],
#         [0.4800],
#         [0.4900],
#         [0.5000],
#         [0.5100],
#         [0.5200],
#         [0.5300],
#         [0.5400],
#         [0.5500],
#         [0.5600],
#         [0.5700],
#         [0.5800],
#         [0.5900],
#         [0.6000],
#         [0.6100],
#         [0.6200],
#         [0.6300],
#         [0.6400],
#         [0.6500],
#         [0.6600],
#         [0.6700],
#         [0.6800],
#         [0.6900]])
# The model test sets are tensor([[0.8000],
#         [0.8200],
#         [0.8400],
#         [0.8600],
#         [0.8800],
#         [0.9000],
#         [0.9200],
#         [0.9400],
#         [0.9600],
#         [0.9800]]) and the preds are tensor([[0.7000],
#         [0.7100],
#         [0.7200],
#         [0.7300],
#         [0.7400],
#         [0.7500],
#         [0.7600],
#         [0.7700],
#         [0.7800],
#         [0.7900]])

# %%
#Plot the prediction 

def plot_predictions(train_data=x_train,
                    train_label=x_label,
                    test_data=y_test,
                    test_label=y_label,[]
                    prediction=None):
    #Plotting the training graph
    plt.scatter(train_data,train_label,c="b",s="5",label="Training data")
    plt.legend(prop={"size":14})
    plt.grid

# %%
plot_predictions()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 plot_predictions()
#
# Cell In[32], line 9, in plot_predictions(train_data, train_label, test_data, test_label, prediction)
#       5                     test_data=y_test,
#       6                     test_label=y_label,
#       7                     prediction=None):
#       8     #Plotting the training graph
# ----> 9     plt.scatter(train_data,train_label,c="b",s="5",label="Training data")
#      10     plt.legend(prop={"size":14})
#      11     plt.grid
#
# File c:\Users\Abhijeet Singh\OneDrive\Documents\AIML\Pytorch\myenvpy\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\Abhijeet Singh\OneDrive\Documents\AIML\Pytorch\myenvpy\Lib\site-packages\matplotlib\pyplot.py:3948, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    3928 @_copy_docstring_and_deprecators(Axes.scatter)
#    3929 def scatter(
#    3930     x: float | ArrayLike,
#    (...)   3946     **kwargs,
#    3947 ) -> PathCollection:
# -> 3948     __ret = gca().scatter(
#    3949         x,
#    3950         y,
#    3951         s=s,
#    3952         c=c,
#    3953         marker=marker,
#    3954         cmap=cmap,
#    3955         norm=norm,
#    3956         vmin=vmin,
#    3957         vmax=vmax,
#    3958         alpha=alpha,
#    3959         linewidths=linewidths,
#    3960         edgecolors=edgecolors,
#    3961         colorizer=colorizer,
#    3962         plotnonfinite=plotnonfinite,
#    3963         **({"data": data} if data is not None else {}),
#    3964         **kwargs,
#    3965     )
#    3966     sci(__ret)
#    3967     return __ret
#
# File c:\Users\Abhijeet Singh\OneDrive\Documents\AIML\Pytorch\myenvpy\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\Abhijeet Singh\OneDrive\Documents\AIML\Pytorch\myenvpy\Lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Abhijeet Singh\OneDrive\Documents\AIML\Pytorch\myenvpy\Lib\site-packages\matplotlib\axes\_axes.py:4945, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    4941 s = np.ma.ravel(s)
#    4942 if (len(s) not in (1, x.size) or
#    4943         (not np.issubdtype(s.dtype, np.floating) and
#    4944          not np.issubdtype(s.dtype, np.integer))):
# -> 4945     raise ValueError(
#    4946         "s must be a scalar, "
#    4947         "or float array-like with the same size as x and y")
#    4949 # get the original edgecolor the user passed before we normalize
#    4950 orig_edgecolor = edgecolors
#
# ValueError: s must be a scalar, or float array-like with the same size as x and y
